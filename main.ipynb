# %%
import os, argparse, urllib.request
import numpy as np

MODEL_URL = "https://storage.googleapis.com/mediapipe-models/hand_landmarker/hand_landmarker/float16/1/hand_landmarker.task"
MODEL_PATH = "hand_landmarker.task"

# %% [markdown]
# ### Downloading mediapipe hand tracker model

# %%
if not os.path.exists(MODEL_PATH):
    print("Downloading hand_landmarker.task ...")
    urllib.request.urlretrieve(MODEL_URL, MODEL_PATH)

# %%
import mediapipe as mp
from mediapipe.tasks import python as mp_python
from mediapipe.tasks.python import vision

mode = "IMAGE"

base_options = mp_python.BaseOptions(model_asset_path=MODEL_PATH)
options = vision.HandLandmarkerOptions(
    base_options=base_options,
    running_mode=vision.RunningMode.IMAGE if mode == "IMAGE" else vision.RunningMode.VIDEO,
    num_hands=1,
    min_hand_detection_confidence=0.5,
    min_hand_presence_confidence=0.5,
    min_tracking_confidence=0.5,
)


task = vision.HandLandmarker.create_from_options(options)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 import mediapipe as mp
#       2 from mediapipe.tasks import python as mp_python
#       3 from mediapipe.tasks.python import vision
#       4
#
# File c:\Users\Row-Huh\Documents\meow\naruto-mediapipe\.venv\Lib\site-packages\mediapipe\__init__.py:15
#       1 # Copyright 2019 - 2022 The MediaPipe Authors.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)     12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
# ---> 15 import mediapipe.tasks.python as tasks
#      16 from mediapipe.tasks.python.vision.core.image import Image
#      17 from mediapipe.tasks.python.vision.core.image import ImageFormat
#
# File c:\Users\Row-Huh\Documents\meow\naruto-mediapipe\.venv\Lib\site-packages\mediapipe\tasks\python\__init__.py:21
#      19 from . import core
#      20 from . import text
# ---> 21 from . import vision
#      23 BaseOptions = core.base_options.BaseOptions
#      25 # Remove unnecessary modules to avoid duplication in API docs.
#
# File c:\Users\Row-Huh\Documents\meow\naruto-mediapipe\.venv\Lib\site-packages\mediapipe\tasks\python\vision\__init__.py:18
#      15 """MediaPipe Tasks Vision API."""
#      17 import mediapipe.tasks.python.vision.core
# ---> 18 import mediapipe.tasks.python.vision.drawing_styles
#      19 import mediapipe.tasks.python.vision.drawing_utils
#      20 import mediapipe.tasks.python.vision.face_detector
#
# File c:\Users\Row-Huh\Documents\meow\naruto-mediapipe\.venv\Lib\site-packages\mediapipe\tasks\python\vision\drawing_styles.py:18
#      14 """MediaPipe solution drawing styles."""
#      16 from typing import Mapping
# ---> 18 from mediapipe.tasks.python.vision import drawing_utils
#      19 from mediapipe.tasks.python.vision import face_landmarker
#      20 from mediapipe.tasks.python.vision import hand_landmarker
#
# File c:\Users\Row-Huh\Documents\meow\naruto-mediapipe\.venv\Lib\site-packages\mediapipe\tasks\python\vision\drawing_utils.py:21
#      18 from typing import Mapping, Optional, Union
#      20 import cv2
# ---> 21 import matplotlib.pyplot as plt
#      22 import numpy as np
#      24 from mediapipe.tasks.python.components.containers import detections as detections_module
#
# File c:\Users\Row-Huh\Documents\meow\naruto-mediapipe\.venv\Lib\site-packages\matplotlib\__init__.py:1289
#    1285     rcParams['backend_fallback'] = False
#    1288 if os.environ.get('MPLBACKEND'):
# -> 1289     rcParams['backend'] = os.environ.get('MPLBACKEND')
#    1292 def get_backend(*, auto_select=True):
#    1293     """
#    1294     Return the name of the current backend.
#    1295
#    (...)   1313     matplotlib.use
#    1314     """
#
# File c:\Users\Row-Huh\Documents\meow\naruto-mediapipe\.venv\Lib\site-packages\matplotlib\__init__.py:781, in RcParams.__setitem__(self, key, val)
#     779     cval = valid_key(val)
#     780 except ValueError as ve:
# --> 781     raise ValueError(f"Key {key}: {ve}") from None
#     782 if key in {"text.hinting_factor", "text.kerning_factor"} and cval is not None:
#     783     _api.warn_deprecated("3.11", name=key, obj_type="rcParam")
#
# ValueError: Key backend: 'module://matplotlib_inline.backend_inline' is not a valid value for backend; supported values are ['gtk3agg', 'gtk3cairo', 'gtk4agg', 'gtk4cairo', 'macosx', 'nbagg', 'notebook', 'qtagg', 'qtcairo', 'qt5agg', 'qt5cairo', 'tkagg', 'tkcairo', 'webagg', 'wx', 'wxagg', 'wxcairo', 'agg', 'cairo', 'pdf', 'pgf', 'ps', 'svg', 'template']
